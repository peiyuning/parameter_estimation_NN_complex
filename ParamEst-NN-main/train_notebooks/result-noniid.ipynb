# %% [markdown]
# # Non-IID Pair-Feature 结果
#
# 这个 notebook 在重新生成的 nonrenewal 轨迹上评估已经训练好的三能级 non-IID pair-feature 估计器。
# 这里的 bCRB 诊断使用一阶马尔可夫 waiting-time 公式：先由 kernel matrix 解析构造平稳 `mu_theta(tau)`、相邻 pair joint 和 `q_theta(tau'|tau)`，再计算 `J_init + (N-1) J_pair`。代码不对截断后的 pair density 或 `q` 做事后重归一化；CSV 里的 capture area 和 Fisher/bCRB stability 是数值积分收敛诊断。最终只应解释 `quadrature_converged=True` 的点。

# %%
# %run ../scripts/evaluate_noniid_results.py

# %%
RESULTS["summary_df"]

# %%
RESULTS["length_df"].head(20)

# %%
RESULTS["bound_df"].head(20)
