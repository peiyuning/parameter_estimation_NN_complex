# %% [markdown]
# # Non-IID Pair-Feature 结果
#
# 这个 notebook 在重新生成的 nonrenewal 轨迹上评估已经训练好的三能级 non-IID pair-feature 估计器。
# 这里的 bCRB 诊断使用一阶马尔可夫 waiting-time 公式：先由 kernel matrix 解析构造平稳 `mu_theta(tau)`、相邻 pair joint 和 `q_theta(tau'|tau)`，再计算 `J_init + (N-1) J_pair`。代码不对截断后的 pair density 或 `q` 做事后重归一化；CSV 里的 capture area 是数值积分误差诊断。

# %%
# %run ../scripts/evaluate_noniid_results.py
# Out:
# project_root = /home/t30/rab/ge48zus/paramest-nn/ParamEst-NN-main
# data_root = /home/t30/rab/ge48zus/paramest-nn/ParamEst-NN-main/data
# output_root = /home/t30/rab/ge48zus/paramest-nn/ParamEst-NN-main/data/result_noniid
# models = ('v', 'shelving', 'lambda', 'ladder')
# device = cpu
# batch_size = 8192
# max_eval_traj = all validation
#
# [v] loading checkpoint and data
# ...

# %%
RESULTS["summary_df"]
# Out:
#       model                                         checkpoint sampling_mode  \
# 3    ladder  /home/t30/rab/ge48zus/paramest-nn/ParamEst-NN-...        noniid
# 2    lambda  /home/t30/rab/ge48zus/paramest-nn/ParamEst-NN-...        noniid
# 1  shelving  /home/t30/rab/ge48zus/paramest-nn/ParamEst-NN-...        noniid
# 0         v  /home/t30/rab/ge48zus/paramest-nn/ParamEst-NN-...        noniid
#
#    n_eval  L_max  best_val_std_mse  rmse_delta_Lmax  rmse_omega_Lmax  K_one  \
# 3  200194     50          0.585025         0.725475         0.785550      4
# 2  200204     50          0.564740         0.740160         0.685628      4
# 1  200203     50          0.582128         0.757148         0.678527      4
# 0  200202     50          0.583919         0.759007         0.663474      4
#
#    M_pair  feature_dim
# 3       4           18
# 2       4           18
# 1       4           18
# 0       4           18

# %%
RESULTS["length_df"].head(20)
# Out:
#      L  n_eval  rmse_delta  rmse_omega  elapsed_s     model
# 18  10  200194    0.795452    1.037515   3.569710    ladder
# 19  15  200194    0.765883    0.938272   3.569710    ladder
# 20  20  200194    0.751214    0.886659   3.569710    ladder
# 21  30  200194    0.736886    0.831746   3.569710    ladder
# 22  40  200194    0.729725    0.803515   3.569710    ladder
# 23  50  200194    0.725475    0.785550   3.569710    ladder
# 12  10  200204    0.819951    1.014695   3.865651    lambda
# 13  15  200204    0.787711    0.891748   3.865651    lambda
# 14  20  200204    0.770637    0.823435   3.865651    lambda
# 15  30  200204    0.754087    0.749473   3.865651    lambda
# 16  40  200204    0.745311    0.710436   3.865651    lambda
# 17  50  200204    0.740160    0.685628   3.865651    lambda
# 6   10  200203    0.820259    1.011565   3.328802  shelving
# 7   15  200203    0.794230    0.887685   3.328802  shelving
# 8   20  200203    0.781415    0.818735   3.328802  shelving
# ...

# %%
RESULTS["bound_df"].head(20)
# Out:
#        model  block_id   L  n_eval  grid_size  tau_max     delta     omega  \
# 18    ladder         0  50     384       2048   1024.0  1.019593  4.302778
# 19    ladder         1  50     384       2048   1024.0  0.272011  0.789400
# 20    ladder         2  50     384       2048   1024.0  1.365011  0.949927
# 21    ladder         3  50     384       2048   1024.0  2.549374  1.185668
# 22    ladder         4  50     384       2048   1024.0  1.434279  3.458289
# 23    ladder         5  50     384       2048   1024.0  2.492319  3.877595
# 12    lambda         0  50     384       2048    640.0  0.996590  4.105146
# 13    lambda         1  50     384       2048    640.0  1.010209  4.546531
# 14    lambda         2  50     384       2048    640.0  1.768436  4.698548
# 15    lambda         3  50     384       2048    640.0  2.040307  1.680770
# 16    lambda         4  50     384       2048    640.0  2.495539  3.713449
# ...
